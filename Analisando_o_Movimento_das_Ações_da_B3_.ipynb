# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexBrasil17/Data_Science_Brasil/blob/main/Analisando_o_Movimento_das_A%C3%A7%C3%B5es_da_B3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analisando Dados das Ações da B3'

# %%
import numpy as np
import pandas as pd
import seaborn as sb
from pandas_datareader import data as wb

# %%
tickers = [ 'COGN3.SA', 'MRFG3.SA', 'VVAR3.SA', 'BBDC4.SA', 'ITUB3.SA']
new_data = pd.DataFrame()
for t in tickers:
    new_data[t] = wb.DataReader(t, data_source = 'yahoo', start = '1995-1-1')['Adj Close']

# %%
new_data.tail()
# Out:
#             COGN3.SA  MRFG3.SA   VVAR3.SA   BBDC4.SA   ITUB3.SA
# Date
# 2020-11-13      4.69     14.93  17.860001  24.010000  25.580000
# 2020-11-16      4.75     14.64  17.820000  25.260000  26.500000
# 2020-11-17      4.87     14.47  17.870001  25.400000  26.469999
# 2020-11-18      5.26     14.90  17.730000  24.620001  25.860001
# 2020-11-19      4.96     14.36  17.430000  24.730000  25.870001

# %%
(new_data/ new_data.iloc[0] * 100).plot(figsize = (18,10));
plt.show()
